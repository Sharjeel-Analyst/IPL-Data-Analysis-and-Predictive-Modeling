# %% [markdown]
# # 🏏 IPL Dataset Analysis with Python

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load data
deliveries_df = pd.read_csv("deliveries.csv")
matches_df = pd.read_csv("matches.csv")

# %%
# Show head and nulls
print("Deliveries Head:")
deliveries_df.head()
# Out:
# Deliveries Head:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
# ...

# %%
print("\nMatches Head:")
matches_df.head()
# Out:
# Matches Head:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
print("\nDeliveries Nulls:")
deliveries_df.isnull().sum()
# Out:
# Deliveries Nulls:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batter                   0
# bowler                   0
# non_striker              0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# extras_type         246795
# is_wicket                0
# player_dismissed    247970
# dismissal_kind      247970
# fielder             251566
# dtype: int64

# %%
print("\nMatches Nulls:")
matches_df.isnull().sum()
# Out:
# Matches Nulls:
# id                    0
# season                0
# city                 51
# date                  0
# match_type            0
# player_of_match       5
# venue                 0
# team1                 0
# team2                 0
# toss_winner           0
# toss_decision         0
# winner                5
# result                0
# result_margin        19
# target_runs           3
# target_overs          3
# super_over            0
# method             1074
# umpire1               0
# umpire2               0
# dtype: int64

# %%
# Descriptive statistics
print("Deliveries Description:")
deliveries_df.describe(include='all')
# Out:
# Deliveries Description:
#             match_id         inning    batting_team    bowling_team  \
# count   2.609200e+05  260920.000000          260920          260920
# unique           NaN            NaN              19              19
# top              NaN            NaN  Mumbai Indians  Mumbai Indians
# freq             NaN            NaN           31437           31505
# mean    9.070665e+05       1.483531             NaN             NaN
# std     3.679913e+05       0.502643             NaN             NaN
# min     3.359820e+05       1.000000             NaN             NaN
# 25%     5.483340e+05       1.000000             NaN             NaN
# 50%     9.809670e+05       1.000000             NaN             NaN
# 75%     1.254066e+06       2.000000             NaN             NaN
# max     1.426312e+06       6.000000             NaN             NaN
#
#                  over           ball   batter    bowler non_striker  \
# ...

# %%
print("\nMatches Description:")
matches_df.describe(include='all')
# Out:
# Matches Description:
#                   id season    city        date match_type player_of_match  \
# count   1.095000e+03   1095    1044        1095       1095            1090
# unique           NaN     17      36         823          8             291
# top              NaN   2013  Mumbai  2008-04-26     League  AB de Villiers
# freq             NaN     76     173           2       1029              25
# mean    9.048283e+05    NaN     NaN         NaN        NaN             NaN
# std     3.677402e+05    NaN     NaN         NaN        NaN             NaN
# min     3.359820e+05    NaN     NaN         NaN        NaN             NaN
# 25%     5.483315e+05    NaN     NaN         NaN        NaN             NaN
# 50%     9.809610e+05    NaN     NaN         NaN        NaN             NaN
# 75%     1.254062e+06    NaN     NaN         NaN        NaN             NaN
# max     1.426312e+06    NaN     NaN         NaN        NaN             NaN
#
# ...

# %%
# display all columns
pd.set_option('display.max_columns', None)

# %%
# Merge data
merged_df = deliveries_df.merge(matches_df, how='left', left_on='match_id', right_on='id')
print("Merged Data Head:")
merged_df.head()
# Out:
# Merged Data Head:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
# ...

# %%
# Top Batters and Bowlers
top_batters = merged_df.groupby("batter")["batsman_runs"].sum().sort_values(ascending=False).head(10).reset_index()
print("Top Run Scorers:")
top_batters
# Out:
# Top Run Scorers:
#            batter  batsman_runs
# 0         V Kohli          8014
# 1        S Dhawan          6769
# 2       RG Sharma          6630
# 3       DA Warner          6567
# 4        SK Raina          5536
# 5        MS Dhoni          5243
# 6  AB de Villiers          5181
# 7        CH Gayle          4997
# 8      RV Uthappa          4954
# 9      KD Karthik          4843

# %%
wickets = merged_df[merged_df["is_wicket"] == 1]
top_bowlers = wickets.groupby("bowler").size().sort_values(ascending=False).head(10).reset_index(name='wickets')
print("Top Wicket Takers:")
top_bowlers
# Out:
# Top Wicket Takers:
#        bowler  wickets
# 0   YS Chahal      213
# 1    DJ Bravo      207
# 2   PP Chawla      201
# 3   SP Narine      200
# 4    R Ashwin      198
# 5     B Kumar      195
# 6  SL Malinga      188
# 7    A Mishra      183
# 8   JJ Bumrah      182
# 9   RA Jadeja      169

# %%
matches_per_season = matches_df["season"].value_counts().sort_index().reset_index()
matches_per_season.columns = ["season", "matches"]
print("Matches per Season:")
matches_per_season
# Out:
# Matches per Season:
#      season  matches
# 0   2007/08       58
# 1      2009       57
# 2   2009/10       60
# 3      2011       73
# 4      2012       74
# 5      2013       76
# 6      2014       60
# 7      2015       59
# 8      2016       60
# 9      2017       59
# 10     2018       60
# 11     2019       60
# 12  2020/21       60
# 13     2021       60
# 14     2022       74
# 15     2023       74
# 16     2024       71

# %%
# Plot Top Batters
plt.figure(figsize=(10, 6))
plt.bar(top_batters["batter"], top_batters["batsman_runs"])
plt.title("Top 10 Run Scorers in IPL")
plt.xlabel("Batter")
plt.ylabel("Total Runs")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### ✅ Summary
#
# - The analysis covers delivery-level and match-level IPL data.
# - We identified top performers using groupby operations.
# - Visualized top 10 run scorers.
# - You can extend this analysis with strike rates, win margins, toss effects, etc.

# %% [markdown]
# ## 📊 Advanced EDA on IPL Dataset

# %%
# Strike Rate = (Total Runs / Total Balls Faced) * 100
batter_stats = merged_df.groupby('batter').agg({
    'batsman_runs': 'sum',
    'ball': 'count'
}).rename(columns={'ball': 'balls_faced'}).reset_index()
batter_stats['strike_rate'] = (batter_stats['batsman_runs'] / batter_stats['balls_faced']) * 100
top_strike_rate = batter_stats[batter_stats['balls_faced'] > 200].sort_values(by='strike_rate', ascending=False).head(10)
print(top_strike_rate)
# Out:
#              batter  batsman_runs  balls_faced  strike_rate
# 433         PD Salt           653          385   169.610390
# 606        T Stubbs           405          239   169.456067
# 617         TM Head           772          458   168.558952
# 39       AD Russell          2488         1515   164.224422
# 208       H Klaasen           993          613   161.990212
# 612        TH David           659          417   158.033573
# 561       SP Narine          1534          984   155.894309
# 585  Shashank Singh           423          272   155.514706
# 396        N Pooran          1769         1143   154.768154
# 323  LS Livingstone           939          609   154.187192

# %%
dismissal_counts = merged_df[merged_df['is_wicket'] == 1]['dismissal_kind'].value_counts()
print("Wicket Types:")
print(dismissal_counts)
# Out:
# Wicket Types:
# dismissal_kind
# caught                   8063
# bowled                   2212
# run out                  1114
# lbw                       800
# caught and bowled         367
# stumped                   358
# retired hurt               15
# hit wicket                 15
# obstructing the field       3
# retired out                 3
# Name: count, dtype: int64

# %%
team_wins = matches_df['winner'].value_counts().head(10)
print("Top Teams by Wins:")
print(team_wins)
# Out:
# Top Teams by Wins:
# winner
# Mumbai Indians                 144
# Chennai Super Kings            138
# Kolkata Knight Riders          131
# Royal Challengers Bangalore    116
# Rajasthan Royals               112
# Sunrisers Hyderabad             88
# Kings XI Punjab                 88
# Delhi Daredevils                67
# Delhi Capitals                  48
# Deccan Chargers                 29
# Name: count, dtype: int64

# %%
venue_counts = matches_df['venue'].value_counts().head(10)
print("Most Common Venues:")
print(venue_counts)
# Out:
# Most Common Venues:
# venue
# Eden Gardens                                  77
# Wankhede Stadium                              73
# M Chinnaswamy Stadium                         65
# Feroz Shah Kotla                              60
# Rajiv Gandhi International Stadium, Uppal     49
# MA Chidambaram Stadium, Chepauk               48
# Sawai Mansingh Stadium                        47
# Dubai International Cricket Stadium           46
# Wankhede Stadium, Mumbai                      45
# Punjab Cricket Association Stadium, Mohali    35
# Name: count, dtype: int64

# %%
venue_counts.head(5).plot(kind='bar', title='Top 5 Most Used Venues', xlabel='Venue', ylabel='Matches Hosted')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🧩 Pie Charts & Box Plots

# %%
# Pie chart of toss decisions
toss_decisions = matches_df['toss_decision'].value_counts()
toss_decisions.plot(kind='pie', autopct='%1.1f%%', startangle=90, title='Toss Decision Distribution')
plt.ylabel('')
plt.show()
